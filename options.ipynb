# %%
import pandas as pd

import yfinance as yf
from yahoo_fin import options as options
from yahoo_fin import stock_info as stocks

# %%
ticker='TSLA'

option_dates = options.get_expiration_dates(ticker)

price = stocks.get_live_price(ticker)

print(option_dates)
# Out:
# ['May 8, 2020', 'May 15, 2020', 'May 22, 2020', 'May 29, 2020', 'June 5, 2020', 'June 19, 2020', 'July 17, 2020', 'August 21, 2020', 'September 18, 2020', 'October 16, 2020', 'November 20, 2020', 'December 18, 2020', 'January 15, 2021', 'March 19, 2021', 'June 18, 2021', 'September 17, 2021', 'January 21, 2022', 'March 18, 2022', 'June 17, 2022']

# %%
option_chain =  options.get_options_chain(ticker,option_dates[0])
option_chain['calls'][option_chain['calls']['Strike']>price-10]
# Out:
#            Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 58   TSLA200508C00695000   2020-05-01 3:59PM EDT   695.0       40.89  39.70
# 59   TSLA200508C00700000   2020-05-01 3:59PM EDT   700.0       38.00  37.00
# 60   TSLA200508C00705000   2020-05-01 3:59PM EDT   705.0       35.06  34.05
# 61   TSLA200508C00710000   2020-05-01 3:59PM EDT   710.0       32.60  31.50
# 62   TSLA200508C00715000   2020-05-01 3:58PM EDT   715.0       30.20  29.05
# 63   TSLA200508C00720000   2020-05-01 3:59PM EDT   720.0       27.77  26.70
# 64   TSLA200508C00725000   2020-05-01 3:59PM EDT   725.0       24.50  24.55
# 65   TSLA200508C00730000   2020-05-01 3:59PM EDT   730.0       23.44  22.35
# 66   TSLA200508C00735000   2020-05-01 3:57PM EDT   735.0       21.52  20.80
# 67   TSLA200508C00740000   2020-05-01 3:59PM EDT   740.0       18.95  18.65
# 68   TSLA200508C00745000   2020-05-01 3:59PM EDT   745.0       17.70  16.90
# ...
